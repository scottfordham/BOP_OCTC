# %% [markdown]
# We are interested in pulling NLDAS-3 forcing data for climate variables:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# NLDAS-3 is published to an AWS server that hosts hourly, daily, and monthly modeled observations.
